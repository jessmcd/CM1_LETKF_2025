# %% [markdown]
# # Out file Quick Check

# %%
filename = 'DBZ_VR.out'
filename='/work/jessica.mcdonald/CM1_LETKF_2025/run/letkf.out'

with open(filename, 'r') as file:
    for line_number, line in enumerate(file, start=1):
        if 'Error' in line:
            print(f"Line {line_number}: {line.strip()}")
# Out:
# Line 4510: LETKF:  Obs Std  |  Root-Mean-Sq-Error  |    Bias    |  Spread (obsErr^2+Hxf_var^2)  |   Consistency Ratio
# Line 5365: LETKF:  Obs Std  |  Root-Mean-Sq-Error  |    Bias    |  Spread (obsErr^2+Hxf_var^2)  |   Consistency Ratio
# Line 6222: LETKF:  Obs Std  |  Root-Mean-Sq-Error  |    Bias    |  Spread (obsErr^2+Hxf_var^2)  |   Consistency Ratio
# Line 7077: LETKF:  Obs Std  |  Root-Mean-Sq-Error  |    Bias    |  Spread (obsErr^2+Hxf_var^2)  |   Consistency Ratio
# Line 7932: LETKF:  Obs Std  |  Root-Mean-Sq-Error  |    Bias    |  Spread (obsErr^2+Hxf_var^2)  |   Consistency Ratio
# Line 8238: Errorcode: 128
# Line 8636: FileNotFoundError: [Errno 2] No such file or directory: '/work/jessica.mcdonald/CM1_LETKF_2025/experiments/test_w/Prior.nc' -> '/work/jessica.mcdonald/CM1_LETKF_2025/experiments/test_w/Prior_2024-05-08_20:50:00.nc'
# Line 8716: FileNotFoundError: [Errno 2] No such file or directory: '/work/jessica.mcdonald/CM1_LETKF_2025/experiments/test_w/Prior.nc' -> '/work/jessica.mcdonald/CM1_LETKF_2025/experiments/test_w/Prior_2024-05-08_21:00:00.nc'
# Line 8796: FileNotFoundError: [Errno 2] No such file or directory: '/work/jessica.mcdonald/CM1_LETKF_2025/experiments/test_w/Prior.nc' -> '/work/jessica.mcdonald/CM1_LETKF_2025/experiments/test_w/Prior_2024-05-08_21:10:00.nc'
# Line 8876: FileNotFoundError: [Errno 2] No such file or directory: '/work/jessica.mcdonald/CM1_LETKF_2025/experiments/test_w/Prior.nc' -> '/work/jessica.mcdonald/CM1_LETKF_2025/experiments/test_w/Prior_2024-05-08_21:20:00.nc'
# Line 8956: FileNotFoundError: [Errno 2] No such file or directory: '/work/jessica.mcdonald/CM1_LETKF_2025/experiments/test_w/Prior.nc' -> '/work/jessica.mcdonald/CM1_LETKF_2025/experiments/test_w/Prior_2024-05-08_21:30:00.nc'
# Line 9036: FileNotFoundError: [Errno 2] No such file or directory: '/work/jessica.mcdonald/CM1_LETKF_2025/experiments/test_w/Prior.nc' -> '/work/jessica.mcdonald/CM1_LETKF_2025/experiments/test_w/Prior_2024-05-08_21:40:00.nc'
# Line 9116: FileNotFoundError: [Errno 2] No such file or directory: '/work/jessica.mcdonald/CM1_LETKF_2025/experiments/test_w/Prior.nc' -> '/work/jessica.mcdonald/CM1_LETKF_2025/experiments/test_w/Prior_2024-05-08_21:50:00.nc'
# Line 9196: FileNotFoundError: [Errno 2] No such file or directory: '/work/jessica.mcdonald/CM1_LETKF_2025/experiments/test_w/Prior.nc' -> '/work/jessica.mcdonald/CM1_LETKF_2025/experiments/test_w/Prior_2024-05-08_22:00:00.nc'

# %% [markdown]
# # CM1 outfile Quick Check

# %%
#cm1.out files are deleted if you're redoing a DA experiment without rerunning the "spin up" time, so these won't contain old errors
experiment = '/work/jessica.mcdonald/CM1_LETKF_2025/experiments/test_w'

import glob 
files = sorted(glob.glob(f'{experiment}/member*/cm1.out'))
for f in files:
    print(f.split('/')[-2])
    with open(f, 'r') as file:
        for line_number, line in enumerate(file, start=1):
            if 'error' in line:
                print(f"Line {line_number}: {line.strip()}")
            if 'denied' in line:
                print(f"Line {line_number}: {line.strip()}")
# Out:
# member001
# Line 31096: netcdf status returned an error:           13  ... stopping program
# Line 31098: Permission denied
# member002
# member003
# member004
# member005
# member006
# member007
# member008
# member009
# member010
# member011
# member012
# member013
# member014
# member015
# member016
# member017
# member018
# member019
# member020
# member021
# member022
# member023
# member024
# member025
# member026
# member027
# member028
# member029
# member030
# member031
# member032
# member033
# member034
# member035
# member036

# %% [markdown]
# # Monitor ongoing experimets
# ## 1. Plot Prior and Posterior compared to obs
# ## 2. Check stats files
# ## 3. Overview of a single member

# %%
import sys
import os
import numpy as N
import math as M
import datetime as DT 
from netCDF4 import *
import datetime

import glob
from optparse import OptionParser
from multiprocessing import Pool
from time import time as timer
#from nc_prior_file import *
#from assim_util import *

sys.path.append('src/')
import state_vector as state
import json
import src.plot_src.ctables as ctables

import ens 
from pyDart import dxy_2_dll
import pandas as pd
import pickle
import numpy as np
import cftime
from fsrc.fpython2 import fstate, addbubbles_box, obs_2_grid3d

import contextlib
import io

def findnearest(array, value):
    array = np.asarray(array)
    return (np.abs(array-value)).argmin()

def get_dbz(analysis_time, fpath):
    name = fpath.split('/')[-2]
    myDTstring = analysis_time.strftime('%Y,%m,%d,%H,%M,%S')
    with open(f'{fpath}{name}.exp', 'rb') as f:
        exper = json.load(f)
    files, myDT = ens.FindRestartFiles(exper, myDTstring, ret_exp=False,);
    
    mystate = ens.read_CM1_ens(files, exper, state_vector=state.Hxf, DateTime=analysis_time)   
    ens.ens_CM1_C2A(mystate)
    ens.ens_CM1_coords(mystate)
    
    obs = ens.ens_GRID_RELECTIVITY(mystate)
    return obs

import xarray as xr
import matplotlib.pyplot as plt
import matplotlib as mpl    
plt.rc('xtick', labelsize=14) 
plt.rc('ytick', labelsize=14) 
plt.rc('axes', labelsize=14, titlesize=18) 
mpl.rcParams.update({"axes.grid" : False, "grid.color": "0.6",  'grid.linestyle':':',
                    'grid.linewidth':1, 'axes.labelweight':'bold', 'legend.framealpha':1.0})

# %%
from ens import mymap
import scipy

# %%
#===============================================================================

def get_dbz_fast(analysis_time, fpath, cref=True, ob_file=None):

    if fpath[-1]=='/': fpath=fpath[:-1]
    name = os.path.basename(fpath)
    
    with open(f'{fpath}/{name}.exp', 'rb') as f: exper = json.load(f)
    
    # These values are set in the experiment dictionary created at the begining of the run
    
    xoffset = exper['xoffset']
    yoffset = exper['yoffset']
    glat    = exper['lat0']
    glon    = exper['lon0']
      
    if ob_file == None:
      ob_file = exper['radar_obs']
    
    ob_f = pd.read_csv(ob_file)
    
    # look for reflectivity +/- 2.5 min 
    
    dt            = datetime.timedelta(0,30)
    begin  = cftime.date2num(analysis_time - dt, "seconds since 1970-01-01 00:00:00")
    ending = cftime.date2num(analysis_time + dt, "seconds since 1970-01-01 00:00:00")
    
    data_mask = (ob_f.utime >= begin) & (ob_f.utime <= ending) &(ob_f.kind==12) # only dbz
    
    odata = ob_f[data_mask]
    
    data    = odata['value'][:]
    lats    = odata['lat'][:]
    lons    = odata['lon'][:]
    hgts    = odata['height'][:]
    
    cm1 = exper['cm1namelist']
    names = [c[1] for c in cm1]
    nx=cm1[np.where(np.array(names)=='nx')[0][0]][2]
    ny=cm1[np.where(np.array(names)=='ny')[0][0]][2]
    nz=cm1[np.where(np.array(names)=='nz')[0][0]][2]
    dx=cm1[np.where(np.array(names)=='dx')[0][0]][2]
    
    fstate_xc = np.arange(0, nx*dx, dx) + dx/2
    fstate_xc += exper['xoffset']
    fstate_yc = np.arange(0, ny*dx, dx) + dx/2
    fstate_yc += exper['yoffset']
    
    temp = xr.open_dataset(sorted(glob.glob(f"{exper['fcst_members'][0]}/*.nc"))[0], decode_timedelta=True)
    fstate_zc=temp.zh.values
    temp.close()
    
    map      = mymap(fstate_xc, fstate_yc, glat, glon)
    xob, yob = map(lons, lats)
    xob, yob = xob+xoffset, yob+yoffset
    
    # The coordinate system here is based on the grid lat0/lon0/hgt0, and the offset grid stored in fstate
    #     ens stores the x/y grid in grid-internal coordinates
    # Create obs list for KDTree query...
    xyz_obs  = np.vstack((hgts,yob,xob))
    obs_list = list(xyz_obs.transpose())
    
    # Create 3D grid arrays for KDTree
    y_array, z_array, x_array = np.meshgrid(fstate_yc, fstate_zc, fstate_xc)
    xyz_grid = np.dstack([z_array.ravel(),y_array.ravel(),x_array.ravel()])[0]
      
    # Use cKDTree to create fast indexing for 3D grid....
    
    mytree = scipy.spatial.cKDTree(xyz_grid)
    distance, indices1D = mytree.query(obs_list)
    
    # these are the integer indices that you now pass into the fortran routine. They
    # are the un-raveled 3D index locations nearest the observation point in the 3D array
    
    kk,jj,ii = np.unravel_index(indices1D, (len(fstate.zc), len(fstate.yc), len(fstate.xc))) 
    dbz3d = obs_2_grid3d(data, xob, yob, hgts, x_array, y_array, z_array, ii, jj, kk, 4000., 2000., 0.0)

    # Create composite reflectivity, and then replicate it into a 3D array
    
    dbz2d = np.zeros((1,))
    
    if cref:
    
        dbz2d = dbz3d.max(axis=0)
    
        for k in np.arange(nz):
            dbz3d[k] = dbz2d
      
    #if verbose: print("\n ==> ens_GRID_REFL: 2D composite DBZ requested   Max:  %4.1f   Min:  %4.1f" % (dbz2d.max(), dbz2d.min()))
    
    del xyz_obs, x_array, y_array, z_array, xyz_grid, mytree
             
    return dbz3d

# %%
#MEMBER = 0

fpath = '/work/jessica.mcdonald/CM1_LETKF_2025/experiments/test_outliers/'
name = fpath.split('/')[-2]
#TIME = 9

for TIME in [7]:#np.arange(10,21,2):

    for MEMBER in [3]:
    
        fig, axes= plt.subplots(1,3, figsize=(12, 4), sharex=True, sharey=True)
        
        
        # read in data
        if MEMBER == 0:
            fig.suptitle(f'Ensemble Mean',x=.19, fontsize=20, weight='bold', y=1.04)
            cm1 = xr.open_dataset(f'{fpath}member{MEMBER:03d}/cm1_post_{TIME:06d}.nc',decode_timedelta=True)
        else:
            fig.suptitle(f'Member {MEMBER}',x=.19, fontsize=20, weight='bold', y=1.04)
            cm1 = xr.open_dataset(f'{fpath}/member{MEMBER:03d}/cm1rst_{TIME:06d}.nc',decode_timedelta=True)

        try:
            prior = xr.open_dataset(f'{fpath}member{MEMBER:03d}/cm1_prior_{TIME:06d}.nc',decode_timedelta=True)
        except:
            print('no prior file, forecast only')
            prior=cm1.copy()
        
        analysis_time = DT.datetime(cm1.year, cm1.month, cm1.day, cm1.hour, cm1.minute)+DT.timedelta(seconds=int(cm1.time.values[0]/1e9))
        with contextlib.redirect_stdout(io.StringIO()) as f: # this just silences all the obnoxious output
            dbz_obs = get_dbz(analysis_time, fpath); # this is cref 
        
        for ax, data in zip(axes, [prior.dbz[0].max(axis=0).values, cm1.dbz[0].max(axis=0).values, dbz_obs[0]]):
            im=ax.contourf(cm1.xh/1000, cm1.yh/1000, data, levels=np.arange(5, 80, 5),cmap=ctables.REF_default, alpha=0.7)
            ax.text(0.98, 0.04, f'max {data.max():.1f}',ha='right', fontsize=14,transform=ax.transAxes )
            
        
        axes[0].set_ylabel('Y (km)')
        for ax, title in zip(axes, ['Prior', 'Posterior', 'Observations']):
            ax.set_title(title, y=1.01, weight='bold')
            ax.set_aspect('equal')
            ax.set_xlabel('X (km)')
            ax.contour(cm1.xh/1000, cm1.yh/1000, dbz_obs[:].max(axis=0), levels=np.arange(5, 80, 10),colors='k', linewidths=0.5)
    
            # center plots on max observations
            z,y,x = np.where(dbz_obs ==dbz_obs.max())
            cx = cm1.xh[x[0]]/1000; cy=cm1.yh[y[0]]/1000
            buf=80
            ax.set_xlim(cx-buf+20, cx+buf+20)
            ax.set_ylim(cy-buf, cy+buf)
    
        
        cbar_ax = fig.add_axes([0.93, 0.1, 0.015, 0.8])
        cbar = fig.colorbar(im, cax=cbar_ax)
        cbar.set_label('Composite Reflectivity (dBZ)', weight='bold')
        plt.subplots_adjust(wspace=0.08, hspace=0.3)
        plt.show()
        
        cm1.close()
        prior.close()
# Out:
#  FORTRAN OBS_2_GRID3D:  dims           128         128          51         911
#  FORTRAN OBS_2_GRID3D:  dx, hscale   3000.00000       4000.00000
#  FORTRAN OBS_2_GRID3D:  dy, hscale   3000.00000       4000.00000
#  FORTRAN OBS_2_GRID3D:  vscale     2000.00000
#  FORTRAN OBS_2_GRID3D:    obs    15.0238209       56.1734352
#  FORTRAN OBS_2_GRID3D:  x-obs   -56735.3398       13770.0430
#  FORTRAN OBS_2_GRID3D:  y-obs   -76280.5938      -26176.0000
#  FORTRAN OBS_2_GRID3D:  z-obs    302.290771       12716.4678
#  FORTRAN OBS_2_GRID3D:  x-grid  -178500.000       202500.000
#  FORTRAN OBS_2_GRID3D:  y-grid  -178500.000       202500.000
#  FORTRAN OBS_2_GRID3D:  z-grid   75.0000000       19700.0000

# %%
# look at stats files to make sure nothing is "blowing up"
# be very careful with this.... it may be locking the stats file and causing big problems for the experiments (?)
mem=3

fig=plt.figure(figsize=(12,8))

for mem in [2]:#np.arange(1,37,1):
    stats = xr.open_dataset(f'{fpath}/member{mem:03d}/cm1out_stats.nc',decode_timedelta=True)
    plt.plot(stats.time/1e9/60, stats.umax, label='Max U', ls='-',alpha=0.7, color='C4', lw=0.5)
    plt.plot(stats.time/1e9/60, stats.vmax, label='Max V', ls='-',alpha=0.7, color='C0', lw=.5)
    plt.plot(stats.time/1e9/60, stats.wmax, label='Max w', ls='-',alpha=0.7, color='k', lw=.5)
    plt.plot(stats.time/1e9/60, stats.maxqv, label='Max w', ls='-',alpha=0.7, color='r', lw=.5)
    for h in np.arange(45, 110, 5):
        plt.axvline(h, color='k', ls=':', lw=1)
    plt.xlabel('Time (Minutes')
    plt.ylabel('m/s')
    #plt.legend()
    stats.close()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 5
#       1 # look at stats files to make sure nothing is "blowing up"
#       2 # be very careful with this.... it may be locking the stats file and causing big problems for the experiments (?)
#       3 mem=3
# ----> 5 fig=plt.figure(figsize=(12,8))
#       7 for mem in [2]:#np.arange(1,37,1):
#       8     stats = xr.open_dataset(f'{fpath}/member{mem:03d}/cm1out_stats.nc',decode_timedelta=True)
#
# NameError: name 'plt' is not defined

# %%
stats
# Out:
# <xarray.Dataset> Size: 41kB
# Dimensions:   (xh: 1, yh: 1, zh: 1, time: 61)
# Coordinates:
#   * xh        (xh) float32 4B 0.0
#   * yh        (yh) float32 4B 0.0
#   * zh        (zh) float32 4B 0.0
#   * time      (time) timedelta64[ns] 488B 00:00:00 00:01:00 ... 01:00:00
# Data variables: (12/167)
#     mtime     (time) float32 244B ...
#     wmax      (time) float32 244B 0.9993 1.014 1.779 2.411 ... 18.68 19.47 19.51
#     wmin      (time) float32 244B ...
#     zwmax     (time) float32 244B ...
#     zwmin     (time) float32 244B ...
#     wmax500   (time) float32 244B ...
#     ...        ...
#     bscci     (time) float32 244B ...
#     bscsw     (time) float32 244B ...
#     bschw     (time) float32 244B ...
#     bschl     (time) float32 244B ...
#     bsvhw     (time) float32 244B ...
#     bsvhl     (time) float32 244B ...
# Attributes:
#     CM1 version:    cm1r21.1
#     Conventions:    CF-1.7
#     missing_value:  -999999.9

# %%
#MEMBER = 0
#TIME = 11

for MEMBER in [4]:

    for TIME in np.arange(5, 28,2):

        fig, ax= plt.subplots(1,1, figsize=(4, 4), sharex=True, sharey=True)
        
        
        # read in data
        if MEMBER == 0:
            fig.suptitle(f'Ensemble Mean', fontsize=20, weight='bold', y=1.01)
            cm1 = xr.open_dataset(f'/work/jessica.mcdonald/CM1_LETKF_2025/RUN_LETKF/member{MEMBER:03d}/cm1_post_{TIME:06d}.nc',decode_timedelta=True)
        else:
            fig.suptitle(f'Member {MEMBER}', fontsize=20, weight='bold', y=1.01)
            cm1 = xr.open_dataset(f'/work/jessica.mcdonald/CM1_LETKF_2025/RUN_LETKF/member{MEMBER:03d}/cm1rst_{TIME:06d}.nc',decode_timedelta=True)
    
        im=ax.contourf(cm1.xh/1000, cm1.yh/1000, cm1.dbz[0].max(axis=0).values, levels=np.arange(10, 80, 5),cmap=ctables.REF_default, alpha=0.5)

        # try:
        #     analysis_time = DT.datetime(cm1.year, cm1.month, cm1.day, cm1.hour, cm1.minute)+DT.timedelta(seconds=int(cm1.time.values[0]/1e9))
        #     with contextlib.redirect_stdout(io.StringIO()) as f: # this just silences all the obnoxious output
        #         dbz_obs = get_dbz(analysis_time); # this is cref 
        #     ax.contour(cm1.xh/1000, cm1.yh/1000, dbz_obs[:].max(axis=0), levels=np.arange(10, 80, 10),colors='k', linewidths=0.5)
        # except:
        #     pass
        
        ax.text(0.98, 0.04, f'max {cm1.dbz[0].max():.1f}',ha='right', fontsize=14,transform=ax.transAxes )
        ax.set_ylabel('Y (km)')
        ax.set_aspect('equal')
        ax.set_xlabel('X (km)')
 
        cbar_ax = fig.add_axes([0.93, 0.1, 0.035, 0.8])
        cbar = fig.colorbar(im, cax=cbar_ax)
        cbar.set_label('Composite Reflectivity (dBZ)', weight='bold')
        plt.subplots_adjust(wspace=0.08, hspace=0.3)
        
        cm1.close()
    #prior.close()
# Out:
# array([   0.,   60.,  120.,  180.,  240.,  300.,  360.,  420.,  480.,
#         540.,  600.,  660.,  720.,  780.,  840.,  900.,  960., 1020.,
#        1080., 1140., 1200., 1260., 1320., 1380., 1440., 1500., 1560.,
#        1620., 1680., 1740., 1800., 1860., 1920., 1980., 2040., 2100.,
#        2160., 2220., 2280., 2340., 2400., 2460., 2520., 2580., 2640.,
#        2700., 2760., 2820., 2880., 2940., 3000., 3060., 3120., 3180.,
#        3240., 3300., 3360., 3420., 3480., 3540., 3600., 3660., 3720.,
#        3780., 3840., 3900., 3960., 4020., 4080., 4140., 4200., 4260.,
#        4320., 4380., 4440., 4500., 4560., 4620., 4680., 4740., 4800.,
#        4860., 4920., 4980., 5040., 5100., 5160., 5220., 5280., 5340.,
#        5400., 5460., 5520., 5580., 5640., 5700., 5760., 5820., 5880.,
#        5940., 6000., 6060., 6120., 6180., 6240., 6300., 6360., 6420.,
#        6480., 6540., 6600., 6660., 6720., 6780., 6840., 6900., 6960.,
#        7020., 7080., 7140., 7200., 7260., 7320., 7380., 7440., 7500.,
#        7560., 7620., 7680., 7740., 7800., 7860., 7920., 7980., 8040.,
#        8100.], dtype=float32)

# %% [markdown]
# # Delete files to redo DA experiments without having to re-run spin up
#
# note: this may break your cm1out_stats files(?)

# %%
import sys
import os
import numpy as np
import math as M
import datetime as DT 
from netCDF4 import *
import glob
import json
sys.path.append('src/')
import ens

# %%
#### REDOING EXPERIMENTS - THIS ALLOWS YOU TO DELETE FROM A SPECIFIED LOCATION TO HELP WITH CM1 BUGS

ARE_YOU_SURE =True
experiment = 'test_w'

start_delete = DT.datetime(2024,5,8,20,0) # will delete all existing files after this time
experiment_location = f'/work/jessica.mcdonald/CM1_LETKF_2025/experiments/{experiment}/'
#experiment_location = f'/work2/jessica.mcdonald/LETKF_work2/AllExperiments/{experiment}/'

exp_length = 240 # minutes... this doesn't have to be exact
outfile_freq = 5 # minutes... how often does cm1 output? 

with open(f'{experiment_location}{experiment}.exp', 'rb') as mf:
    exper = json.load(mf)


delete_list = []
# for i,rtime in enumerate(np.arange(start_delete, start_delete+DT.timedelta(minutes=exp_length+outfile_freq),DT.timedelta(minutes=outfile_freq) )):
#     rtime = rtime.astype(DT.datetime)

#     if i == 0: # find the cm1 ID for your specified start time, so you can loop over higher numbers
#         files, myDT = ens.FindRestartFiles(exper, rtime.strftime('%Y,%m,%d,%H,%M,%S'), ret_exp=False,)
#         start_num = int(files[0].split('.')[-2][-2:]) + 1 # you shouldn't delete that time step

#     inf = experiment_location+rtime.strftime('Inflation_%Y-%m-%d_%H:%M:%S.nc')
#     prior = experiment_location+rtime.strftime('Prior_%Y-%m-%d_%H:%M:%S.nc')
#     cm1out = experiment_location+'cm1.out'
#     delete_list.extend([inf, prior])

#start_num=24 # you can manually set the number if you'd prefer (and you don't care about inflation or prior files)
#start_num=4
        
# for each member, get rid of anything after the start delete time      
for i in range(1, exper['ne']+1):
    main = experiment_location+f'member{i:03d}/'
    delete_list.append(main+f'cm1.out')
    for oi in range(start_num, int(exp_length/outfile_freq),1):
        delete_list.append(main+f'cm1rst_{oi:06d}.nc')
        delete_list.append(main+f'cm1_prior_{oi:06d}.nc')
         
for d in delete_list:
    if os.path.exists(d):
        cmd = f'rm {d}'
        if ARE_YOU_SURE:
            os.system(cmd)
        else:            
            print(cmd)

# %%
delete_list
# Out:
# ['/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/Inflation_2024-05-08_20:35:00.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/Prior_2024-05-08_20:35:00.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/Inflation_2024-05-08_20:40:00.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/Prior_2024-05-08_20:40:00.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/Inflation_2024-05-08_20:45:00.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/Prior_2024-05-08_20:45:00.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/Inflation_2024-05-08_20:50:00.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/Prior_2024-05-08_20:50:00.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/Inflation_2024-05-08_20:55:00.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/Prior_2024-05-08_20:55:00.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/Inflation_2024-05-08_21:00:00.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/Prior_2024-05-08_21:00:00.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/Inflation_2024-05-08_21:05:00.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/Prior_2024-05-08_21:05:00.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/Inflation_2024-05-08_21:10:00.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/Prior_2024-05-08_21:10:00.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/Inflation_2024-05-08_21:15:00.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/Prior_2024-05-08_21:15:00.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/Inflation_2024-05-08_21:20:00.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/Prior_2024-05-08_21:20:00.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/Inflation_2024-05-08_21:25:00.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/Prior_2024-05-08_21:25:00.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/Inflation_2024-05-08_21:30:00.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/Prior_2024-05-08_21:30:00.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/Inflation_2024-05-08_21:35:00.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/Prior_2024-05-08_21:35:00.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/Inflation_2024-05-08_21:40:00.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/Prior_2024-05-08_21:40:00.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/Inflation_2024-05-08_21:45:00.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/Prior_2024-05-08_21:45:00.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/Inflation_2024-05-08_21:50:00.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/Prior_2024-05-08_21:50:00.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/Inflation_2024-05-08_21:55:00.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/Prior_2024-05-08_21:55:00.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/Inflation_2024-05-08_22:00:00.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/Prior_2024-05-08_22:00:00.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/Inflation_2024-05-08_22:05:00.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/Prior_2024-05-08_22:05:00.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/Inflation_2024-05-08_22:10:00.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/Prior_2024-05-08_22:10:00.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/Inflation_2024-05-08_22:15:00.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/Prior_2024-05-08_22:15:00.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/Inflation_2024-05-08_22:20:00.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/Prior_2024-05-08_22:20:00.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/Inflation_2024-05-08_22:25:00.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/Prior_2024-05-08_22:25:00.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/Inflation_2024-05-08_22:30:00.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/Prior_2024-05-08_22:30:00.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/Inflation_2024-05-08_22:35:00.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/Prior_2024-05-08_22:35:00.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/Inflation_2024-05-08_22:40:00.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/Prior_2024-05-08_22:40:00.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/Inflation_2024-05-08_22:45:00.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/Prior_2024-05-08_22:45:00.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/Inflation_2024-05-08_22:50:00.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/Prior_2024-05-08_22:50:00.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/Inflation_2024-05-08_22:55:00.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/Prior_2024-05-08_22:55:00.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/Inflation_2024-05-08_23:00:00.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/Prior_2024-05-08_23:00:00.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/Inflation_2024-05-08_23:05:00.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/Prior_2024-05-08_23:05:00.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/Inflation_2024-05-08_23:10:00.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/Prior_2024-05-08_23:10:00.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/Inflation_2024-05-08_23:15:00.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/Prior_2024-05-08_23:15:00.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/Inflation_2024-05-08_23:20:00.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/Prior_2024-05-08_23:20:00.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/Inflation_2024-05-08_23:25:00.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/Prior_2024-05-08_23:25:00.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/Inflation_2024-05-08_23:30:00.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/Prior_2024-05-08_23:30:00.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/Inflation_2024-05-08_23:35:00.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/Prior_2024-05-08_23:35:00.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/Inflation_2024-05-08_23:40:00.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/Prior_2024-05-08_23:40:00.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/Inflation_2024-05-08_23:45:00.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/Prior_2024-05-08_23:45:00.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/Inflation_2024-05-08_23:50:00.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/Prior_2024-05-08_23:50:00.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/Inflation_2024-05-08_23:55:00.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/Prior_2024-05-08_23:55:00.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/Inflation_2024-05-09_00:00:00.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/Prior_2024-05-09_00:00:00.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/Inflation_2024-05-09_00:05:00.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/Prior_2024-05-09_00:05:00.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/Inflation_2024-05-09_00:10:00.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/Prior_2024-05-09_00:10:00.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/Inflation_2024-05-09_00:15:00.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/Prior_2024-05-09_00:15:00.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/Inflation_2024-05-09_00:20:00.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/Prior_2024-05-09_00:20:00.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/Inflation_2024-05-09_00:25:00.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/Prior_2024-05-09_00:25:00.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/Inflation_2024-05-09_00:30:00.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/Prior_2024-05-09_00:30:00.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/Inflation_2024-05-09_00:35:00.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/Prior_2024-05-09_00:35:00.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member001/cm1.out',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member001/cm1rst_000016.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member001/cm1_prior_000016.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member001/cm1rst_000017.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member001/cm1_prior_000017.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member001/cm1rst_000018.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member001/cm1_prior_000018.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member001/cm1rst_000019.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member001/cm1_prior_000019.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member001/cm1rst_000020.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member001/cm1_prior_000020.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member001/cm1rst_000021.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member001/cm1_prior_000021.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member001/cm1rst_000022.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member001/cm1_prior_000022.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member001/cm1rst_000023.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member001/cm1_prior_000023.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member001/cm1rst_000024.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member001/cm1_prior_000024.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member001/cm1rst_000025.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member001/cm1_prior_000025.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member001/cm1rst_000026.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member001/cm1_prior_000026.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member001/cm1rst_000027.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member001/cm1_prior_000027.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member001/cm1rst_000028.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member001/cm1_prior_000028.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member001/cm1rst_000029.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member001/cm1_prior_000029.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member001/cm1rst_000030.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member001/cm1_prior_000030.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member001/cm1rst_000031.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member001/cm1_prior_000031.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member001/cm1rst_000032.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member001/cm1_prior_000032.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member001/cm1rst_000033.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member001/cm1_prior_000033.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member001/cm1rst_000034.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member001/cm1_prior_000034.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member001/cm1rst_000035.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member001/cm1_prior_000035.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member001/cm1rst_000036.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member001/cm1_prior_000036.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member001/cm1rst_000037.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member001/cm1_prior_000037.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member001/cm1rst_000038.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member001/cm1_prior_000038.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member001/cm1rst_000039.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member001/cm1_prior_000039.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member001/cm1rst_000040.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member001/cm1_prior_000040.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member001/cm1rst_000041.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member001/cm1_prior_000041.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member001/cm1rst_000042.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member001/cm1_prior_000042.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member001/cm1rst_000043.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member001/cm1_prior_000043.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member001/cm1rst_000044.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member001/cm1_prior_000044.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member001/cm1rst_000045.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member001/cm1_prior_000045.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member001/cm1rst_000046.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member001/cm1_prior_000046.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member001/cm1rst_000047.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member001/cm1_prior_000047.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member002/cm1.out',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member002/cm1rst_000016.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member002/cm1_prior_000016.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member002/cm1rst_000017.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member002/cm1_prior_000017.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member002/cm1rst_000018.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member002/cm1_prior_000018.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member002/cm1rst_000019.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member002/cm1_prior_000019.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member002/cm1rst_000020.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member002/cm1_prior_000020.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member002/cm1rst_000021.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member002/cm1_prior_000021.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member002/cm1rst_000022.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member002/cm1_prior_000022.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member002/cm1rst_000023.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member002/cm1_prior_000023.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member002/cm1rst_000024.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member002/cm1_prior_000024.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member002/cm1rst_000025.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member002/cm1_prior_000025.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member002/cm1rst_000026.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member002/cm1_prior_000026.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member002/cm1rst_000027.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member002/cm1_prior_000027.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member002/cm1rst_000028.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member002/cm1_prior_000028.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member002/cm1rst_000029.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member002/cm1_prior_000029.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member002/cm1rst_000030.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member002/cm1_prior_000030.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member002/cm1rst_000031.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member002/cm1_prior_000031.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member002/cm1rst_000032.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member002/cm1_prior_000032.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member002/cm1rst_000033.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member002/cm1_prior_000033.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member002/cm1rst_000034.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member002/cm1_prior_000034.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member002/cm1rst_000035.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member002/cm1_prior_000035.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member002/cm1rst_000036.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member002/cm1_prior_000036.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member002/cm1rst_000037.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member002/cm1_prior_000037.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member002/cm1rst_000038.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member002/cm1_prior_000038.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member002/cm1rst_000039.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member002/cm1_prior_000039.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member002/cm1rst_000040.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member002/cm1_prior_000040.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member002/cm1rst_000041.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member002/cm1_prior_000041.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member002/cm1rst_000042.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member002/cm1_prior_000042.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member002/cm1rst_000043.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member002/cm1_prior_000043.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member002/cm1rst_000044.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member002/cm1_prior_000044.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member002/cm1rst_000045.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member002/cm1_prior_000045.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member002/cm1rst_000046.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member002/cm1_prior_000046.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member002/cm1rst_000047.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member002/cm1_prior_000047.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member003/cm1.out',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member003/cm1rst_000016.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member003/cm1_prior_000016.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member003/cm1rst_000017.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member003/cm1_prior_000017.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member003/cm1rst_000018.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member003/cm1_prior_000018.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member003/cm1rst_000019.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member003/cm1_prior_000019.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member003/cm1rst_000020.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member003/cm1_prior_000020.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member003/cm1rst_000021.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member003/cm1_prior_000021.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member003/cm1rst_000022.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member003/cm1_prior_000022.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member003/cm1rst_000023.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member003/cm1_prior_000023.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member003/cm1rst_000024.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member003/cm1_prior_000024.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member003/cm1rst_000025.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member003/cm1_prior_000025.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member003/cm1rst_000026.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member003/cm1_prior_000026.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member003/cm1rst_000027.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member003/cm1_prior_000027.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member003/cm1rst_000028.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member003/cm1_prior_000028.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member003/cm1rst_000029.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member003/cm1_prior_000029.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member003/cm1rst_000030.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member003/cm1_prior_000030.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member003/cm1rst_000031.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member003/cm1_prior_000031.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member003/cm1rst_000032.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member003/cm1_prior_000032.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member003/cm1rst_000033.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member003/cm1_prior_000033.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member003/cm1rst_000034.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member003/cm1_prior_000034.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member003/cm1rst_000035.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member003/cm1_prior_000035.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member003/cm1rst_000036.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member003/cm1_prior_000036.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member003/cm1rst_000037.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member003/cm1_prior_000037.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member003/cm1rst_000038.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member003/cm1_prior_000038.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member003/cm1rst_000039.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member003/cm1_prior_000039.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member003/cm1rst_000040.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member003/cm1_prior_000040.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member003/cm1rst_000041.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member003/cm1_prior_000041.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member003/cm1rst_000042.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member003/cm1_prior_000042.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member003/cm1rst_000043.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member003/cm1_prior_000043.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member003/cm1rst_000044.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member003/cm1_prior_000044.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member003/cm1rst_000045.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member003/cm1_prior_000045.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member003/cm1rst_000046.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member003/cm1_prior_000046.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member003/cm1rst_000047.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member003/cm1_prior_000047.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member004/cm1.out',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member004/cm1rst_000016.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member004/cm1_prior_000016.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member004/cm1rst_000017.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member004/cm1_prior_000017.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member004/cm1rst_000018.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member004/cm1_prior_000018.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member004/cm1rst_000019.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member004/cm1_prior_000019.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member004/cm1rst_000020.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member004/cm1_prior_000020.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member004/cm1rst_000021.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member004/cm1_prior_000021.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member004/cm1rst_000022.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member004/cm1_prior_000022.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member004/cm1rst_000023.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member004/cm1_prior_000023.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member004/cm1rst_000024.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member004/cm1_prior_000024.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member004/cm1rst_000025.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member004/cm1_prior_000025.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member004/cm1rst_000026.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member004/cm1_prior_000026.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member004/cm1rst_000027.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member004/cm1_prior_000027.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member004/cm1rst_000028.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member004/cm1_prior_000028.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member004/cm1rst_000029.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member004/cm1_prior_000029.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member004/cm1rst_000030.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member004/cm1_prior_000030.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member004/cm1rst_000031.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member004/cm1_prior_000031.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member004/cm1rst_000032.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member004/cm1_prior_000032.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member004/cm1rst_000033.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member004/cm1_prior_000033.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member004/cm1rst_000034.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member004/cm1_prior_000034.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member004/cm1rst_000035.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member004/cm1_prior_000035.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member004/cm1rst_000036.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member004/cm1_prior_000036.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member004/cm1rst_000037.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member004/cm1_prior_000037.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member004/cm1rst_000038.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member004/cm1_prior_000038.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member004/cm1rst_000039.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member004/cm1_prior_000039.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member004/cm1rst_000040.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member004/cm1_prior_000040.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member004/cm1rst_000041.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member004/cm1_prior_000041.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member004/cm1rst_000042.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member004/cm1_prior_000042.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member004/cm1rst_000043.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member004/cm1_prior_000043.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member004/cm1rst_000044.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member004/cm1_prior_000044.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member004/cm1rst_000045.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member004/cm1_prior_000045.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member004/cm1rst_000046.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member004/cm1_prior_000046.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member004/cm1rst_000047.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member004/cm1_prior_000047.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member005/cm1.out',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member005/cm1rst_000016.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member005/cm1_prior_000016.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member005/cm1rst_000017.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member005/cm1_prior_000017.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member005/cm1rst_000018.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member005/cm1_prior_000018.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member005/cm1rst_000019.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member005/cm1_prior_000019.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member005/cm1rst_000020.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member005/cm1_prior_000020.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member005/cm1rst_000021.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member005/cm1_prior_000021.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member005/cm1rst_000022.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member005/cm1_prior_000022.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member005/cm1rst_000023.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member005/cm1_prior_000023.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member005/cm1rst_000024.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member005/cm1_prior_000024.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member005/cm1rst_000025.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member005/cm1_prior_000025.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member005/cm1rst_000026.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member005/cm1_prior_000026.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member005/cm1rst_000027.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member005/cm1_prior_000027.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member005/cm1rst_000028.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member005/cm1_prior_000028.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member005/cm1rst_000029.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member005/cm1_prior_000029.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member005/cm1rst_000030.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member005/cm1_prior_000030.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member005/cm1rst_000031.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member005/cm1_prior_000031.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member005/cm1rst_000032.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member005/cm1_prior_000032.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member005/cm1rst_000033.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member005/cm1_prior_000033.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member005/cm1rst_000034.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member005/cm1_prior_000034.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member005/cm1rst_000035.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member005/cm1_prior_000035.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member005/cm1rst_000036.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member005/cm1_prior_000036.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member005/cm1rst_000037.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member005/cm1_prior_000037.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member005/cm1rst_000038.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member005/cm1_prior_000038.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member005/cm1rst_000039.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member005/cm1_prior_000039.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member005/cm1rst_000040.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member005/cm1_prior_000040.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member005/cm1rst_000041.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member005/cm1_prior_000041.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member005/cm1rst_000042.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member005/cm1_prior_000042.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member005/cm1rst_000043.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member005/cm1_prior_000043.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member005/cm1rst_000044.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member005/cm1_prior_000044.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member005/cm1rst_000045.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member005/cm1_prior_000045.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member005/cm1rst_000046.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member005/cm1_prior_000046.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member005/cm1rst_000047.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member005/cm1_prior_000047.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member006/cm1.out',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member006/cm1rst_000016.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member006/cm1_prior_000016.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member006/cm1rst_000017.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member006/cm1_prior_000017.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member006/cm1rst_000018.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member006/cm1_prior_000018.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member006/cm1rst_000019.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member006/cm1_prior_000019.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member006/cm1rst_000020.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member006/cm1_prior_000020.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member006/cm1rst_000021.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member006/cm1_prior_000021.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member006/cm1rst_000022.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member006/cm1_prior_000022.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member006/cm1rst_000023.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member006/cm1_prior_000023.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member006/cm1rst_000024.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member006/cm1_prior_000024.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member006/cm1rst_000025.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member006/cm1_prior_000025.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member006/cm1rst_000026.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member006/cm1_prior_000026.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member006/cm1rst_000027.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member006/cm1_prior_000027.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member006/cm1rst_000028.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member006/cm1_prior_000028.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member006/cm1rst_000029.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member006/cm1_prior_000029.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member006/cm1rst_000030.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member006/cm1_prior_000030.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member006/cm1rst_000031.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member006/cm1_prior_000031.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member006/cm1rst_000032.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member006/cm1_prior_000032.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member006/cm1rst_000033.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member006/cm1_prior_000033.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member006/cm1rst_000034.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member006/cm1_prior_000034.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member006/cm1rst_000035.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member006/cm1_prior_000035.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member006/cm1rst_000036.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member006/cm1_prior_000036.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member006/cm1rst_000037.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member006/cm1_prior_000037.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member006/cm1rst_000038.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member006/cm1_prior_000038.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member006/cm1rst_000039.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member006/cm1_prior_000039.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member006/cm1rst_000040.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member006/cm1_prior_000040.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member006/cm1rst_000041.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member006/cm1_prior_000041.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member006/cm1rst_000042.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member006/cm1_prior_000042.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member006/cm1rst_000043.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member006/cm1_prior_000043.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member006/cm1rst_000044.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member006/cm1_prior_000044.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member006/cm1rst_000045.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member006/cm1_prior_000045.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member006/cm1rst_000046.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member006/cm1_prior_000046.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member006/cm1rst_000047.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member006/cm1_prior_000047.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member007/cm1.out',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member007/cm1rst_000016.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member007/cm1_prior_000016.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member007/cm1rst_000017.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member007/cm1_prior_000017.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member007/cm1rst_000018.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member007/cm1_prior_000018.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member007/cm1rst_000019.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member007/cm1_prior_000019.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member007/cm1rst_000020.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member007/cm1_prior_000020.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member007/cm1rst_000021.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member007/cm1_prior_000021.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member007/cm1rst_000022.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member007/cm1_prior_000022.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member007/cm1rst_000023.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member007/cm1_prior_000023.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member007/cm1rst_000024.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member007/cm1_prior_000024.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member007/cm1rst_000025.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member007/cm1_prior_000025.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member007/cm1rst_000026.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member007/cm1_prior_000026.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member007/cm1rst_000027.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member007/cm1_prior_000027.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member007/cm1rst_000028.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member007/cm1_prior_000028.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member007/cm1rst_000029.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member007/cm1_prior_000029.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member007/cm1rst_000030.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member007/cm1_prior_000030.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member007/cm1rst_000031.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member007/cm1_prior_000031.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member007/cm1rst_000032.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member007/cm1_prior_000032.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member007/cm1rst_000033.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member007/cm1_prior_000033.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member007/cm1rst_000034.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member007/cm1_prior_000034.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member007/cm1rst_000035.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member007/cm1_prior_000035.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member007/cm1rst_000036.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member007/cm1_prior_000036.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member007/cm1rst_000037.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member007/cm1_prior_000037.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member007/cm1rst_000038.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member007/cm1_prior_000038.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member007/cm1rst_000039.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member007/cm1_prior_000039.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member007/cm1rst_000040.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member007/cm1_prior_000040.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member007/cm1rst_000041.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member007/cm1_prior_000041.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member007/cm1rst_000042.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member007/cm1_prior_000042.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member007/cm1rst_000043.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member007/cm1_prior_000043.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member007/cm1rst_000044.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member007/cm1_prior_000044.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member007/cm1rst_000045.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member007/cm1_prior_000045.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member007/cm1rst_000046.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member007/cm1_prior_000046.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member007/cm1rst_000047.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member007/cm1_prior_000047.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member008/cm1.out',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member008/cm1rst_000016.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member008/cm1_prior_000016.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member008/cm1rst_000017.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member008/cm1_prior_000017.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member008/cm1rst_000018.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member008/cm1_prior_000018.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member008/cm1rst_000019.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member008/cm1_prior_000019.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member008/cm1rst_000020.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member008/cm1_prior_000020.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member008/cm1rst_000021.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member008/cm1_prior_000021.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member008/cm1rst_000022.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member008/cm1_prior_000022.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member008/cm1rst_000023.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member008/cm1_prior_000023.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member008/cm1rst_000024.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member008/cm1_prior_000024.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member008/cm1rst_000025.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member008/cm1_prior_000025.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member008/cm1rst_000026.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member008/cm1_prior_000026.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member008/cm1rst_000027.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member008/cm1_prior_000027.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member008/cm1rst_000028.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member008/cm1_prior_000028.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member008/cm1rst_000029.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member008/cm1_prior_000029.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member008/cm1rst_000030.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member008/cm1_prior_000030.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member008/cm1rst_000031.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member008/cm1_prior_000031.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member008/cm1rst_000032.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member008/cm1_prior_000032.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member008/cm1rst_000033.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member008/cm1_prior_000033.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member008/cm1rst_000034.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member008/cm1_prior_000034.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member008/cm1rst_000035.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member008/cm1_prior_000035.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member008/cm1rst_000036.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member008/cm1_prior_000036.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member008/cm1rst_000037.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member008/cm1_prior_000037.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member008/cm1rst_000038.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member008/cm1_prior_000038.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member008/cm1rst_000039.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member008/cm1_prior_000039.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member008/cm1rst_000040.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member008/cm1_prior_000040.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member008/cm1rst_000041.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member008/cm1_prior_000041.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member008/cm1rst_000042.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member008/cm1_prior_000042.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member008/cm1rst_000043.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member008/cm1_prior_000043.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member008/cm1rst_000044.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member008/cm1_prior_000044.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member008/cm1rst_000045.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member008/cm1_prior_000045.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member008/cm1rst_000046.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member008/cm1_prior_000046.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member008/cm1rst_000047.nc',
# ...
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member011/cm1_prior_000038.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member011/cm1rst_000039.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member011/cm1_prior_000039.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member011/cm1rst_000040.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member011/cm1_prior_000040.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member011/cm1rst_000041.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member011/cm1_prior_000041.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member011/cm1rst_000042.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member011/cm1_prior_000042.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member011/cm1rst_000043.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member011/cm1_prior_000043.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member011/cm1rst_000044.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member011/cm1_prior_000044.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member011/cm1rst_000045.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member011/cm1_prior_000045.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member011/cm1rst_000046.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member011/cm1_prior_000046.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member011/cm1rst_000047.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member011/cm1_prior_000047.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member012/cm1.out',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member012/cm1rst_000016.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member012/cm1_prior_000016.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member012/cm1rst_000017.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member012/cm1_prior_000017.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member012/cm1rst_000018.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member012/cm1_prior_000018.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member012/cm1rst_000019.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member012/cm1_prior_000019.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member012/cm1rst_000020.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member012/cm1_prior_000020.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member012/cm1rst_000021.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member012/cm1_prior_000021.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member012/cm1rst_000022.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member012/cm1_prior_000022.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member012/cm1rst_000023.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member012/cm1_prior_000023.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member012/cm1rst_000024.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member012/cm1_prior_000024.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member012/cm1rst_000025.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member012/cm1_prior_000025.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member012/cm1rst_000026.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member012/cm1_prior_000026.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member012/cm1rst_000027.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member012/cm1_prior_000027.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member012/cm1rst_000028.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member012/cm1_prior_000028.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member012/cm1rst_000029.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member012/cm1_prior_000029.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member012/cm1rst_000030.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member012/cm1_prior_000030.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member012/cm1rst_000031.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member012/cm1_prior_000031.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member012/cm1rst_000032.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member012/cm1_prior_000032.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member012/cm1rst_000033.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member012/cm1_prior_000033.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member012/cm1rst_000034.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member012/cm1_prior_000034.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member012/cm1rst_000035.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member012/cm1_prior_000035.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member012/cm1rst_000036.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member012/cm1_prior_000036.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member012/cm1rst_000037.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member012/cm1_prior_000037.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member012/cm1rst_000038.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member012/cm1_prior_000038.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member012/cm1rst_000039.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member012/cm1_prior_000039.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member012/cm1rst_000040.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member012/cm1_prior_000040.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member012/cm1rst_000041.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member012/cm1_prior_000041.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member012/cm1rst_000042.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member012/cm1_prior_000042.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member012/cm1rst_000043.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member012/cm1_prior_000043.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member012/cm1rst_000044.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member012/cm1_prior_000044.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member012/cm1rst_000045.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member012/cm1_prior_000045.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member012/cm1rst_000046.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member012/cm1_prior_000046.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member012/cm1rst_000047.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member012/cm1_prior_000047.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member013/cm1.out',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member013/cm1rst_000016.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member013/cm1_prior_000016.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member013/cm1rst_000017.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member013/cm1_prior_000017.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member013/cm1rst_000018.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member013/cm1_prior_000018.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member013/cm1rst_000019.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member013/cm1_prior_000019.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member013/cm1rst_000020.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member013/cm1_prior_000020.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member013/cm1rst_000021.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member013/cm1_prior_000021.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member013/cm1rst_000022.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member013/cm1_prior_000022.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member013/cm1rst_000023.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member013/cm1_prior_000023.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member013/cm1rst_000024.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member013/cm1_prior_000024.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member013/cm1rst_000025.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member013/cm1_prior_000025.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member013/cm1rst_000026.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member013/cm1_prior_000026.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member013/cm1rst_000027.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member013/cm1_prior_000027.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member013/cm1rst_000028.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member013/cm1_prior_000028.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member013/cm1rst_000029.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member013/cm1_prior_000029.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member013/cm1rst_000030.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member013/cm1_prior_000030.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member013/cm1rst_000031.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member013/cm1_prior_000031.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member013/cm1rst_000032.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member013/cm1_prior_000032.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member013/cm1rst_000033.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member013/cm1_prior_000033.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member013/cm1rst_000034.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member013/cm1_prior_000034.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member013/cm1rst_000035.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member013/cm1_prior_000035.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member013/cm1rst_000036.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member013/cm1_prior_000036.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member013/cm1rst_000037.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member013/cm1_prior_000037.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member013/cm1rst_000038.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member013/cm1_prior_000038.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member013/cm1rst_000039.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member013/cm1_prior_000039.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member013/cm1rst_000040.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member013/cm1_prior_000040.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member013/cm1rst_000041.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member013/cm1_prior_000041.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member013/cm1rst_000042.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member013/cm1_prior_000042.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member013/cm1rst_000043.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member013/cm1_prior_000043.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member013/cm1rst_000044.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member013/cm1_prior_000044.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member013/cm1rst_000045.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member013/cm1_prior_000045.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member013/cm1rst_000046.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member013/cm1_prior_000046.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member013/cm1rst_000047.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member013/cm1_prior_000047.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member014/cm1.out',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member014/cm1rst_000016.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member014/cm1_prior_000016.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member014/cm1rst_000017.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member014/cm1_prior_000017.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member014/cm1rst_000018.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member014/cm1_prior_000018.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member014/cm1rst_000019.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member014/cm1_prior_000019.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member014/cm1rst_000020.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member014/cm1_prior_000020.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member014/cm1rst_000021.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member014/cm1_prior_000021.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member014/cm1rst_000022.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member014/cm1_prior_000022.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member014/cm1rst_000023.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member014/cm1_prior_000023.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member014/cm1rst_000024.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member014/cm1_prior_000024.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member014/cm1rst_000025.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member014/cm1_prior_000025.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member014/cm1rst_000026.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member014/cm1_prior_000026.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member014/cm1rst_000027.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member014/cm1_prior_000027.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member014/cm1rst_000028.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member014/cm1_prior_000028.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member014/cm1rst_000029.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member014/cm1_prior_000029.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member014/cm1rst_000030.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member014/cm1_prior_000030.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member014/cm1rst_000031.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member014/cm1_prior_000031.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member014/cm1rst_000032.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member014/cm1_prior_000032.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member014/cm1rst_000033.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member014/cm1_prior_000033.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member014/cm1rst_000034.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member014/cm1_prior_000034.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member014/cm1rst_000035.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member014/cm1_prior_000035.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member014/cm1rst_000036.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member014/cm1_prior_000036.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member014/cm1rst_000037.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member014/cm1_prior_000037.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member014/cm1rst_000038.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member014/cm1_prior_000038.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member014/cm1rst_000039.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member014/cm1_prior_000039.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member014/cm1rst_000040.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member014/cm1_prior_000040.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member014/cm1rst_000041.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member014/cm1_prior_000041.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member014/cm1rst_000042.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member014/cm1_prior_000042.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member014/cm1rst_000043.nc',
#  '/work/jessica.mcdonald/CM1_LETKF_2025/DBZ_VR/member014/cm1_prior_000043.nc',
#  ...]
